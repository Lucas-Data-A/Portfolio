# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
dados = {
    'id': [1, 2, 3],
    'nome': ['Lucas', 'Marina', 'João'],
    'idade': [28, 25, 30]
}

df = pd.DataFrame(dados)

# %%
df
# Out:
#    id    nome  idade
# 0   1   Lucas     28
# 1   2  Marina     25
# 2   3    João     30

# %%
engine = create_engine("postgresql+psycopg2://postgres:Naruto120@localhost:5432/testes")

df.to_sql("pessoas", engine, if_exists="replace", index=False)

engine.dispose()

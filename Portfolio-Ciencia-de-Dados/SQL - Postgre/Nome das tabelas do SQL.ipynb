# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql+psycopg2://postgres:Naruto120@localhost:5432/testes")

# %%
from sqlalchemy import inspect
insp = inspect(engine)
print(insp.get_table_names(schema='public'))
# Out:
# ['pessoas', 'produtos', 'categorias', 'caquinha', 'categoria', 'ordens', 'produto', 'vendasproj2']

# %%
engine.dispose()

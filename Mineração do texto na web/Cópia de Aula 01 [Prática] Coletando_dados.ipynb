# %%
# !curl https://www.cesar.org.br/
# Out:
# <!DOCTYPE html><html lang="pt-BR"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="stylesheet" href="/_next/static/css/ad88ad475a9e55d8.css" data-precedence="next"/><link rel="preload" as="script" fetchPriority="low" href="/_next/static/chunks/webpack-3d41b5c770860551.js"/><script src="/_next/static/chunks/fd9d1056-314fb114d841eb7e.js" async=""></script><script src="/_next/static/chunks/8069-f0e047fc6ec3fb76.js" async=""></script><script src="/_next/static/chunks/main-app-4d1564f0311960d9.js" async=""></script><script src="/_next/static/chunks/8e1d74a4-8284df32ae86d909.js" async=""></script><script src="/_next/static/chunks/7232-6f6d372ac3f96b5f.js" async=""></script><script src="/_next/static/chunks/8338-54958717e12e920b.js" async=""></script><script src="/_next/static/chunks/5935-f926eacca7e614df.js" async=""></script><script src="/_next/static/chunks/703-e58f5af99cdfcfe5.js" async=""></script><script src="/_next/static/ch
# ...

# %%
# !wget https://www.cesar.org.br/
# Out:
# --2025-05-20 22:26:10--  https://www.cesar.org.br/
# Resolving www.cesar.org.br (www.cesar.org.br)... 13.249.126.68, 13.249.126.95, 13.249.126.115, ...
# Connecting to www.cesar.org.br (www.cesar.org.br)|13.249.126.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 254133 (248K) [text/html]
# Saving to: ‘index.html’
#
# index.html          100%[===================>] 248.18K  1.23MB/s    in 0.2s
#
# 2025-05-20 22:26:11 (1.23 MB/s) - ‘index.html’ saved [254133/254133]

# %% [markdown]
# # O Selenium só pode ser executado na maquina local, para funcionar no colab é necessário fazer vários ajustes os quais não vem ao caso.
# ## Intalar o drive do chrome
#
#
# ```
# sudo apt install chromium-chromedriver
# ```
#
# ## Intslar o selenium
#
#
# ```
# pip install selenium
# ```
#
# ## O Código a baixo permite de forma local, acessar o site do cesar e printas o HTML da página, um exemplo simples que mostra como o Selenium pode ser usado
#
# ```
# from selenium import webdriver
# driver = webdriver.Chrome()
# driver.get('https://www.cesar.org.br')
# html = driver.page_source
# print(html)
# ```

# %% [markdown]
# Usando Pandas

# %%
# !pip install pandas lxml html5lib

# %%
import pandas as pd
page = pd.read_html('https://en.wikipedia.org/wiki/Curitiba')
print(page[1])
# Out:
#    Climate data for Curitiba (1991–2020 normals, extremes 1885–present)  \
#                                                                   Month
# 0                                 Record high °C (°F)
# 1                          Mean daily maximum °C (°F)
# 2                                  Daily mean °C (°F)
# 3                          Mean daily minimum °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6                 Average precipitation days (≥ 1 mm)
# 7                       Average relative humidity (%)
# 8                           Average dew point °C (°F)
# 9                         Mean monthly sunshine hours
# 10                          Average ultraviolet index
# 11  Source 1: Instituto Nacional de Meteorologia[3...
# 12  Source 2: Meteo Climat (record highs and lows)...
#
#                                                        \
#                                                   Jan
# ...

# %% [markdown]
# ### Erro esperado
# O código a baixo executava até ano passado, isso significa que o texto da planilha foi alterado.

# %%
print(page[1]['Climate data for Recife (1991-2020; extremes 1961-present)'].keys())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Climate data for Recife (1991-2020; extremes 1961-present)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-ea8744556d2b> in <cell line: 0>()
# ...

# %%
print(page[1]['Climate data for Curitiba (1991–2020 normals, extremes 1885–present)'].keys())
# Out:
# Index(['Month', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'Year'],
#       dtype='object')

# %%
print(page[1]['Climate data for Curitiba (1991–2020 normals, extremes 1885–present)']['Jan'])
# Out:
# 0                                           34.3 (93.7)
# 1                                           27.1 (80.8)
# 2                                           21.3 (70.3)
# 3                                           17.6 (63.7)
# 4                                            8.2 (46.8)
# 5                                          226.3 (8.91)
# 6                                                  15.4
# 7                                                  80.6
# 8                                           18.2 (64.8)
# 9                                                 161.9
# 10                                                   12
# 11    Source 1: Instituto Nacional de Meteorologia[3...
# 12    Source 2: Meteo Climat (record highs and lows)...
# Name: Jan, dtype: object
